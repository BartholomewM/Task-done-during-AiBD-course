# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from os import path
import plot_rates

df_all = pd.read_csv("../Analysis Data/malopolski_copy.csv")
df_beko = pd.read_csv("../Analysis Data/futher changes/Beko.csv")
df_dyson = pd.read_csv("../Analysis Data/futher changes/Dyson.csv")
df_electrolux = pd.read_csv("../Analysis Data/futher changes/Electrolux.csv")
df_samsung = pd.read_csv("../Analysis Data/futher changes/samsung.csv")
df_tefal = pd.read_csv("../Analysis Data/futher changes/tefal.csv")

xlab = "ocena"
ylab = "ilość ocen"

# %%
x, y = plot_rates.rates(df_all)
plot_rates.plot_data(x, y, "rozkład ocen dla wszystkich ocen", xlab, ylab)

# %%
x, y = plot_rates.rates(df_beko)
plot_rates.plot_data(x, y, "", xlab, ylab)

# %%
x, y = plot_rates.rates(df_dyson)
plot_rates.plot_data(x, y, "", xlab, ylab)

# %%
x, y = plot_rates.rates(df_electrolux)
plot_rates.plot_data(x, y, "", xlab, ylab)

# %%
x, y = plot_rates.rates(df_samsung)
plot_rates.plot_data(x, y, "", xlab, ylab)

# %%
x, y = plot_rates.rates(df_tefal)
plot_rates.plot_data(x, y, "", xlab, ylab)
