# %%
import os

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from os import path
import file
import rates

df_all = pd.read_csv("../Analysis Data/malopolski_copy.csv")
df_beko = pd.read_csv("../Analysis Data/futher changes/Beko.csv")
df_dyson = pd.read_csv("../Analysis Data/futher changes/Dyson.csv")
df_electrolux = pd.read_csv("../Analysis Data/futher changes/Electrolux.csv")
df_samsung = pd.read_csv("../Analysis Data/futher changes/samsung.csv")
df_tefal = pd.read_csv("../Analysis Data/futher changes/tefal.csv")

# %%
x, y = file.gender_statistics(df_all)
file.plot_data3(x, y, "płć dla każdej marki")

# %%
x, y = file.gender_statistics(df_beko)
file.plot_data3(x, y, "płć dla każdej beko")

# %%
x, y = file.gender_statistics(df_dyson)
file.plot_data3(x, y, "płć dla każdej dysona")

# %%
x, y = file.gender_statistics(df_electrolux)
file.plot_data3(x, y, "płć dla każdej elctrolux")

# %%
x, y = file.gender_statistics(df_samsung)
file.plot_data3(x, y, "płć dla każdej samsunga")

# %%
x, y = file.gender_statistics(df_tefal)
file.plot_data3(x, y, "płć dla każdej tefal")
